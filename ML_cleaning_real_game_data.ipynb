# %%
#this code creates and cleans the data to use in the testing of my model;
#this is real game data from recent games;
#import dependencies;
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
df_1 = pd.read_excel('2019_real_match_data.xlsx', sheet_name='Sheet2')

# %%
df_2019 = pd.DataFrame(df_1)

df_2019[0:-1]
# Out:
#      gameid                                                url  league  \
# 0   1163171  http://matchhistory.na.leagueoflegends.com/en/...     LCS
# 1    gameid                                                url  league
# 2   1163171  http://matchhistory.na.leagueoflegends.com/en/...     LCS
# 3   1163171  http://matchhistory.na.leagueoflegends.com/en/...     LCS
# 4    990452  http://matchhistory.na.leagueoflegends.com/en/...     LEC
# 5    990452  http://matchhistory.na.leagueoflegends.com/en/...     LEC
# 6   1162715  http://matchhistory.na.leagueoflegends.com/en/...     LCS
# 7   1162715  http://matchhistory.na.leagueoflegends.com/en/...     LCS
# 8    990415  http://matchhistory.na.leagueoflegends.com/en/...     LEC
# 9    990415  http://matchhistory.na.leagueoflegends.com/en/...     LEC
# 10  1162877  https://matchhistory.na.leagueoflegends.com/en...     LCK
# 11  1162877  https://matchhistory.na.leagueoflegends.com/en...     LCK
# ...

# %%
df_2019_sorted = df_2019.loc[df_2019['playerid'].isin([100, 200])]

# df_2019_cleaned = df_2019_sorted.dropna()

matchups_df = df_2019_sorted.loc[df_2019_sorted['side'] == 'Blue']

# %%
matchups_df['team']
# Out:
# 0               Cloud9
# 2               Cloud9
# 4           G2 Esports
# 6          Team Liquid
# 8        Excel Esports
# 10             Griffin
# 12          KT Rolster
# 14        Team SoloMid
# 16    Golden Guardians
# 18         Team Liquid
# Name: team, dtype: object

# %%
# Export file as a CSV, without the Pandas index, but with the header
matchups_df.to_csv("2019_matchups.csv", index=False, header=True)
