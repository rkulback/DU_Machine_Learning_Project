# %%
#this code creates and cleans the data and uploads it to a mySQL database;
#import dependencies
# Dependencies
import json
import requests
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
df_1 = pd.read_excel('2019_summer.xlsx', sheet_name='Sheet1')

# %%
df_2019_summer = pd.DataFrame(df_1)

df_2019_summer.head()
# Out:
#     gameid                                                url league   split  \
# 0  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 1  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 2  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 3  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 4  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
#
#       date  week  game  patchno  playerid  side  ... gdat15  xpat10 oppxpat10  \
# 0  43617.6   1.0     1      9.1         1  Blue  ... -668.0  4453.0    5258.0
# 1  43617.6   1.0     1      9.1         2  Blue  ...  546.0  3876.0    3255.0
# 2  43617.6   1.0     1      9.1         3  Blue  ...  402.0  4973.0    4549.0
# 3  43617.6   1.0     1      9.1         4  Blue  ...  406.0  3275.0    3002.0
# 4  43617.6   1.0     1      9.1         5  Blue  ...  -15.0  2683.0    2557.0
#
# ...

# %%
df_2019_summer.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
df_2019_summer_sorted = df_2019_summer.loc[df_2019_summer['playerid'].isin([100, 200])]

df_2019_summer_cleaned = df_2019_summer_sorted.dropna()

# %%
df_2019_summer_cleaned.head()
# Out:
#      gameid                                                url league   split  \
# 10  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 11  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 22  1092362  https://matchhistory.na.leagueoflegends.com/en...    LCS  2019-2
# 23  1092362  https://matchhistory.na.leagueoflegends.com/en...    LCS  2019-2
# 34  1092372  https://matchhistory.na.leagueoflegends.com/en...    LCS  2019-2
#
#        date  week  game  patchno  playerid  side  ...  gdat15   xpat10  \
# 10  43617.6   1.0     1      9.1       100  Blue  ...   671.0  19260.0
# 11  43617.6   1.0     1      9.1       200   Red  ...  -671.0  18621.0
# 22  43617.7   1.0     1      9.1       100  Blue  ...  4373.0  19015.0
# 23  43617.7   1.0     1      9.1       200   Red  ... -4373.0  18226.0
# 34  43617.7   1.0     1      9.1       100  Blue  ...  3557.0  19284.0
#
# ...

# %%
## now to get the 2019 spring matches

df_2 = pd.read_excel('2019_spring.xlsx', sheet_name='Sheet1')

df_2019_spring = pd.DataFrame(df_2)

df_2019_spring.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
df_2019_spring_sorted = df_2019_spring.loc[df_2019_spring['playerid'].isin([100, 200])]

df_2019_spring_cleaned = df_2019_spring_sorted.dropna()

# %%
df_2019_spring_cleaned.head()
# Out:
#     gameid                                                url league   split  \
# 10  980560  https://matchhistory.euw.leagueoflegends.com/e...    LEC  2019-1
# 11  980560  https://matchhistory.euw.leagueoflegends.com/e...    LEC  2019-1
# 22  980572  https://matchhistory.euw.leagueoflegends.com/e...    LEC  2019-1
# 23  980572  https://matchhistory.euw.leagueoflegends.com/e...    LEC  2019-1
# 34  980590  https://matchhistory.euw.leagueoflegends.com/e...    LEC  2019-1
#
#        date week game  patchno  playerid  side  ...  gdat15   xpat10  \
# 10  43483.5    1    1     9.01       100  Blue  ... -2047.0  18459.0
# 11  43483.5    1    1     9.01       200   Red  ...  2047.0  19689.0
# 22  43483.6    1    1     9.01       100  Blue  ... -1312.0  17729.0
# 23  43483.6    1    1     9.01       200   Red  ...  1312.0  18782.0
# 34  43483.6    1    1     9.01       100  Blue  ...   -68.0  19198.0
#
#    oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15  csdat15
# ...

# %%
## now to get the 2018 summer matches

df_3 = pd.read_excel('2018_summer.xlsx', sheet_name='Sheet1')

df_2018_summer = pd.DataFrame(df_3)

df_2018_summer.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
df_2018_summer_sorted = df_2018_summer.loc[df_2018_summer['playerid'].isin([100, 200])]

# %%
df_2018_summer_cleaned = df_2018_summer_sorted.dropna()

# %%
df_2018_summer_cleaned.head()
# Out:
#         gameid                                                url league  \
# 22  1002570087  https://matchhistory.na.leagueoflegends.com/en...  EULCS
# 23  1002570087  https://matchhistory.na.leagueoflegends.com/en...  EULCS
# 34      730084  https://matchhistory.br.leagueoflegends.com/pt...  CBLoL
# 35      730084  https://matchhistory.br.leagueoflegends.com/pt...  CBLoL
# 46      730095  https://matchhistory.br.leagueoflegends.com/pt...  CBLoL
#
#      split     date week game  patchno  playerid  side  ...  gdat15   xpat10  \
# 22  2018-2  43274.5    2    2     8.12       100  Blue  ...  2832.0  18379.0
# 23  2018-2  43274.5    2    2     8.12       200   Red  ... -2832.0  17670.0
# 34  2018-2  43260.5  1.1    1     8.11       100  Blue  ...   -74.0  17439.0
# 35  2018-2  43260.5  1.1    1     8.11       200   Red  ...    74.0  18615.0
# 46  2018-2  43260.5  1.1    2     8.11       100  Blue  ...  1761.0  18369.0
#
# ...

# %%
## now to get the 2018 summer matches

df_4 = pd.read_excel('2018_spring.xlsx', sheet_name='Sheet1')

df_2018_spring = pd.DataFrame(df_4)

df_2018_spring.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
df_2018_spring_sorted = df_2018_spring.loc[df_2018_spring['playerid'].isin([100, 200])]

# %%
df_2018_spring_cleaned = df_2018_spring_sorted.dropna()

# %%
df_2018_spring_cleaned.head()
# Out:
#     gameid                                                url league   split  \
# 10  550246  https://matchhistory.na.leagueoflegends.com/en...    LCK  2018-1
# 11  550246  https://matchhistory.na.leagueoflegends.com/en...    LCK  2018-1
# 22  550247  https://matchhistory.na.leagueoflegends.com/en...    LCK  2018-1
# 23  550247  https://matchhistory.na.leagueoflegends.com/en...    LCK  2018-1
# 34  550268  https://matchhistory.na.leagueoflegends.com/en...    LCK  2018-1
#
#        date week game  patchno  playerid  side  ...  gdat15   xpat10  \
# 10  43116.1  1.1    1     8.01       100  Blue  ...   -55.0  19103.0
# 11  43116.1  1.1    1     8.01       200   Red  ...    55.0  17702.0
# 22  43116.2  1.1    2     8.01       100  Blue  ... -1402.0  19035.0
# 23  43116.2  1.1    2     8.01       200   Red  ...  1402.0  19811.0
# 34  43116.2  1.1    1     8.01       100  Blue  ...   -78.0  19772.0
#
#    oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15  csdat15
# ...

# %%
## now to get the 2017 matches

df_5 = pd.read_excel('2017.xlsx', sheet_name='Sheet1')

df_2017 = pd.DataFrame(df_5)

df_2017.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
df_2017_sorted = df_2017.loc[df_2017['playerid'].isin([100, 200])]

# %%
df_2017_cleaned = df_2017_sorted.dropna()

# %%
df_2017_cleaned.head()
# Out:
#          gameid                                                url league  \
# 10   1002300127  http://matchhistory.na.leagueoflegends.com/en/...  NALCS
# 11   1002300127  http://matchhistory.na.leagueoflegends.com/en/...  NALCS
# 118      240145  http://matchhistory.na.leagueoflegends.com/en/...   NACS
# 119      240145  http://matchhistory.na.leagueoflegends.com/en/...   NACS
# 154      240148  http://matchhistory.na.leagueoflegends.com/en/...   NACS
#
#       split     date week game  patchno  playerid  side  ...  gdat15   xpat10  \
# 10   2017-2  42953.7  9.3    3     7.15       100  Blue  ... -3854.0  18625.0
# 11   2017-2  42953.7  9.3    3     7.15       200   Red  ...  3854.0  18807.0
# 118  2017-2  42929.7  5.2    1     7.13       100  Blue  ... -1283.0  17739.0
# 119  2017-2  42929.7  5.2    1     7.13       200   Red  ...  1283.0  18289.0
# 154  2017-2  42929.7  5.2    2     7.13       100  Blue  ...  4830.0  19356.0
#
# ...

# %%
dfs = [df_2019_spring_cleaned, df_2019_summer_cleaned,
      df_2018_summer_cleaned, df_2018_spring_cleaned,
      df_2017_cleaned]

result = pd.concat(dfs).reset_index()

# %%
result.head()
# Out:
#    index  gameid                                                url league  \
# 0     10  980560  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 1     11  980560  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 2     22  980572  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 3     23  980572  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 4     34  980590  https://matchhistory.euw.leagueoflegends.com/e...    LEC
#
#     split     date week game  patchno  playerid  ...  gdat15   xpat10  \
# 0  2019-1  43483.5    1    1     9.01       100  ... -2047.0  18459.0
# 1  2019-1  43483.5    1    1     9.01       200  ...  2047.0  19689.0
# 2  2019-1  43483.6    1    1     9.01       100  ... -1312.0  17729.0
# 3  2019-1  43483.6    1    1     9.01       200  ...  1312.0  18782.0
# 4  2019-1  43483.6    1    1     9.01       100  ...   -68.0  19198.0
#
#   oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15 csdat15
# ...

# %%
result.columns
# Out:
# Index(['index', 'gameid', 'url', 'league', 'split', 'date', 'week', 'game',
#        'patchno', 'playerid', 'side', 'position', 'player', 'team', 'champion',
#        'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k',
#        'd', 'a', 'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras',
#        'pentas', 'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm',
#        'fd', 'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
#        'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
# ...

# %%
raw_combined_df = result[['gameid', 'league', 'playerid', 'side', 'gamelength', 'team',
                        'result', 'teamkills', 'teamdeaths', 'a', 'fb', 'fbtime', 
                        'teamdragkills', 'oppdragkills', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft',
                       'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
                        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
                        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute',
                        'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
                         'visionwards', 'totalgold', 'minionkills', 'monsterkills', 'monsterkillsownjungle',
                         'monsterkillsenemyjungle', 'cspm', 'goldat10', 'oppgoldat10', 'gdat10',
                         'goldat15', 'oppgoldat15', 'gdat15', 'xpat10', 'oppxpat10', 'xpdat10',
                         'csat10', 'oppcsat10', 'csdat10', 'csat15', 'oppcsat15', 'csdat15'
                        ]]

# %%
raw_combined_df.head()
# Out:
#    gameid league  playerid  side  gamelength           team  result  \
# 0  980560    LEC       100  Blue   30.816667         Fnatic       0
# 1  980560    LEC       200   Red   30.816667      SK Gaming       1
# 2  980572    LEC       100  Blue   38.166667         Splyce       1
# 3  980572    LEC       200   Red   38.166667  Excel Esports       0
# 4  980590    LEC       100  Blue   31.600000       Vitality       0
#
#    teamkills  teamdeaths     a  ...  gdat15   xpat10  oppxpat10  xpdat10  \
# 0       12.0        11.0  26.0  ... -2047.0  18459.0    19689.0  -1230.0
# 1       11.0        12.0  23.0  ...  2047.0  19689.0    18459.0   1230.0
# 2       16.0         6.0  43.0  ... -1312.0  17729.0    18782.0  -1053.0
# 3        6.0        16.0  16.0  ...  1312.0  18782.0    17729.0   1053.0
# 4        8.0        12.0  16.0  ...   -68.0  19198.0    19628.0   -430.0
#
#    csat10  oppcsat10  csdat10  csat15  oppcsat15  csdat15
# 0   334.0      350.0    -16.0   554.0      562.0     -8.0
# ...

# %%
#combine side and result so that i can measure blue side success

raw_combined_df['blue_result'] = raw_combined_df.side.astype(str).str.cat(raw_combined_df.result.astype(str), sep=" , ")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
master_df = raw_combined_df.drop(['side', 'result'], axis=1)

master_df.head()
# Out:
#    gameid league  playerid  gamelength           team  teamkills  teamdeaths  \
# 0  980560    LEC       100   30.816667         Fnatic       12.0        11.0
# 1  980560    LEC       200   30.816667      SK Gaming       11.0        12.0
# 2  980572    LEC       100   38.166667         Splyce       16.0         6.0
# 3  980572    LEC       200   38.166667  Excel Esports        6.0        16.0
# 4  980590    LEC       100   31.600000       Vitality        8.0        12.0
#
#       a fb   fbtime  ...   xpat10  oppxpat10  xpdat10  csat10  oppcsat10  \
# 0  26.0  0   5.3722  ...  18459.0    19689.0  -1230.0   334.0      350.0
# 1  23.0  1   5.3722  ...  19689.0    18459.0   1230.0   350.0      334.0
# 2  43.0  1  6.99108  ...  17729.0    18782.0  -1053.0   302.0      292.0
# 3  16.0  0  6.99108  ...  18782.0    17729.0   1053.0   292.0      302.0
# 4  16.0  0  4.06207  ...  19198.0    19628.0   -430.0   326.0      332.0
#
#    csdat10  csat15  oppcsat15  csdat15  blue_result
# ...

# %%
#replace the values to a cleaner name

master_df.replace('Blue , 0', 'blue loss', inplace=True)
master_df.replace('Blue , 1', 'blue win', inplace=True)
master_df.replace('Red , 1', 'blue loss', inplace=True)
master_df.replace('Red , 0', 'blue win', inplace=True)

# %%
master_df.head()
# Out:
#    gameid league  playerid  gamelength           team  teamkills  teamdeaths  \
# 0  980560    LEC       100   30.816667         Fnatic       12.0        11.0
# 1  980560    LEC       200   30.816667      SK Gaming       11.0        12.0
# 2  980572    LEC       100   38.166667         Splyce       16.0         6.0
# 3  980572    LEC       200   38.166667  Excel Esports        6.0        16.0
# 4  980590    LEC       100   31.600000       Vitality        8.0        12.0
#
#       a  fb    fbtime  ...   xpat10  oppxpat10  xpdat10  csat10  oppcsat10  \
# 0  26.0   0  5.372200  ...  18459.0    19689.0  -1230.0   334.0      350.0
# 1  23.0   1  5.372200  ...  19689.0    18459.0   1230.0   350.0      334.0
# 2  43.0   1  6.991083  ...  17729.0    18782.0  -1053.0   302.0      292.0
# 3  16.0   0  6.991083  ...  18782.0    17729.0   1053.0   292.0      302.0
# 4  16.0   0  4.062067  ...  19198.0    19628.0   -430.0   326.0      332.0
#
#    csdat10  csat15  oppcsat15  csdat15  blue_result
# ...

# %%
# master_df.sort_values('gameid', inplace=True)

master_df.drop_duplicates(subset='gameid', inplace=True)

# %%
master_df.head()
# Out:
#    gameid league  playerid  gamelength      team  teamkills  teamdeaths     a  \
# 0  980560    LEC       100   30.816667    Fnatic       12.0        11.0  26.0
# 2  980572    LEC       100   38.166667    Splyce       16.0         6.0  43.0
# 4  980590    LEC       100   31.600000  Vitality        8.0        12.0  16.0
# 6  990708    LEC       100   24.550000     Rogue        3.0        12.0   6.0
# 7  990721    LEC       100   27.233333    Origen        5.0        19.0   6.0
#
#    fb    fbtime  ...   xpat10  oppxpat10  xpdat10  csat10  oppcsat10  csdat10  \
# 0   0  5.372200  ...  18459.0    19689.0  -1230.0   334.0      350.0    -16.0
# 2   1  6.991083  ...  17729.0    18782.0  -1053.0   302.0      292.0     10.0
# 4   0  4.062067  ...  19198.0    19628.0   -430.0   326.0      332.0     -6.0
# 6   0  2.490617  ...  18476.0    18799.0   -323.0   329.0      316.0     13.0
# 7   1  8.510200  ...  19635.0    19598.0     37.0   344.0      339.0      5.0
#
# ...

# %%
############ create a 10 min game dataframe

game_10_min_df = result[['gameid', 'league', 'playerid', 'side', 'gamelength', 'team',
                        'result', 'goldat10', 'oppgoldat10', 'gdat10',
                         'xpat10', 'oppxpat10', 'xpdat10', 'csat10', 'oppcsat10', 'csdat10'
                        ]]

# %%
game_10_min_df['blue_result'] = game_10_min_df.side.astype(str).str.cat(game_10_min_df.result.astype(str), sep=" , ")

game_10_min_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    gameid league  playerid  side  gamelength           team  result  goldat10  \
# 0  980560    LEC       100  Blue   30.816667         Fnatic       0   15304.0
# 1  980560    LEC       200   Red   30.816667      SK Gaming       1   16764.0
# 2  980572    LEC       100  Blue   38.166667         Splyce       1   14971.0
# 3  980572    LEC       200   Red   38.166667  Excel Esports       0   15578.0
# 4  980590    LEC       100  Blue   31.600000       Vitality       0   15724.0
#
#    oppgoldat10  gdat10   xpat10  oppxpat10  xpdat10  csat10  oppcsat10  \
# ...

# %%
master_10_min_df = game_10_min_df.drop(['side', 'result'], axis=1)

# master_df.sort_values('gameid', inplace=True)

master_10_min_df.drop_duplicates(subset='gameid', inplace=True)



# Export file as a CSV, without the Pandas index, but with the header
master_10_min_df.to_csv("master_10_min_data.csv", index=False, header=True)

# %%
# Export file as a CSV, without the Pandas index, but with the header
master_df.to_csv("2019_machine_learning_data.csv", index=False, header=True)

# %%
### now to read my champion book dataframe and try to apply champion-specific stats to each matchup


# Store filepath in a variable
champion_path = "champion_matchups_2019_table.csv"

# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
champion_stats_book = pd.read_csv(champion_path, encoding="ISO-8859-1")

# %%
champion_stats_book.head()
# Out:
#    game_id  jg_result           jg_matchup      jg_k      jg_a      jg_d  \
# 0  1131400   blue win    Skarner , Rek'Sai  1.916667  7.166667  0.916667
# 1  1144855   blue win  Jarvan IV , Hecarim  4.000000  9.500000  3.500000
# 2  1092075   blue win   Gragas , Jarvan IV  2.250000  7.500000  1.500000
# 3  1124632   blue win       Gragas , Sylas  5.000000  9.500000  2.000000
# 4  1121998  blue loss    Skarner , Rek'Sai  1.916667  7.166667  0.916667
#
#    jg_cs    jg_op_cs       jg_gold     jg_damage  ...  sup_result  \
# 0   90.0   93.583333  11273.416667   4207.666667  ...    blue win
# 1  101.0  107.500000  13534.000000   8771.000000  ...    blue win
# 2   83.0   91.666667  11376.000000  10066.333333  ...    blue win
# 3   98.0   87.000000  15218.000000  24118.000000  ...    blue win
# 4   90.0   93.583333  11273.416667   4207.666667  ...   blue loss
#
#              sup_matchup sup_k      sup_a     sup_d     sup_cs  sup_op_cs  \
# ...

# %%
dfs_2019 = [df_2019_spring_cleaned, df_2019_summer_cleaned]

results_2019 = pd.concat(dfs_2019).reset_index()

results_2019.head()
# Out:
#    index  gameid                                                url league  \
# 0     10  980560  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 1     11  980560  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 2     22  980572  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 3     23  980572  https://matchhistory.euw.leagueoflegends.com/e...    LEC
# 4     34  980590  https://matchhistory.euw.leagueoflegends.com/e...    LEC
#
#     split     date week game  patchno  playerid  ...  gdat15   xpat10  \
# 0  2019-1  43483.5    1    1     9.01       100  ... -2047.0  18459.0
# 1  2019-1  43483.5    1    1     9.01       200  ...  2047.0  19689.0
# 2  2019-1  43483.6    1    1     9.01       100  ... -1312.0  17729.0
# 3  2019-1  43483.6    1    1     9.01       200  ...  1312.0  18782.0
# 4  2019-1  43483.6    1    1     9.01       100  ...   -68.0  19198.0
#
#   oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15 csdat15
# ...
